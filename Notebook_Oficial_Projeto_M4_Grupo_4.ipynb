# %% [markdown]
# #**Data Science: Analisando os Dados da Agência Nacional do Petróleo, Gás Natural e Biocombustíveis**
# *Projeto Módulo 4 | Guilherme Rezende, Letícia Felippe, Liora Dopacio, Tatiany Castelhano, Raian Porto*
#
# ---
# <img alt="Colaboratory logo" width="100%" src="https://clickpetroleoegas.com.br/wp-content/uploads/2020/10/ANP-860x483.jpeg">

# %% [markdown]
# ## Metodologia do Projeto
#
# O projeto foi desenvolvido em cima de análise exploratória e estatítica descritiva. Sendo dividio em seis etapas: *entender o negócio, entender e preparar os dados, limpeza de dados, consultas em Pandas, Numpy e Seaborn, análise exploratória e estatística descritiva com comentários em markdowns*
#
# ---
# <img alt="Colaboratory logo" width="100%" src="https://advancedinstitute.ai/wp-content/uploads/2019/04/analise_dados-1170x500.png">

# %% [markdown]
# ### **A. Entendendo o Negócio:**
#
# Serão apresentados os objetivos do negócio, avaliado quais os problemas a serem resolvidos, bem como determinado mais dois problemas de negócio que agreguem valor de negócio e ajudem na tomada de decisões significativas.

# %% [markdown]
# # **Primeira etapa: importando as bibliotecas pandas e numpy.**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Aqui é feita a importação da tabela referente ao mês de Junho.**

# %%
df_junho = pd.read_csv('2021-06-gasolina-etanol.csv', sep=';')
df_junho
# Out:
#       Região - Sigla  ...                      Bandeira
# 0                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 1                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 2                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 3                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 4                  N  ...                        BRANCA
# ...              ...  ...                           ...
# 49732             NE  ...                        BRANCA
# 49733             NE  ...                        BRANCA
# 49734             SE  ...                        BRANCA
# 49735             SE  ...                        BRANCA
# 49736             SE  ...                        BRANCA
#
# [49737 rows x 16 columns]

# %% [markdown]
# # **O mesmo procedimento foi realizado com a tabela de Julho.**

# %%
df_julho = pd.read_csv('2021-07-gasolina-etanol.csv', sep=';')
df_julho
# Out:
#       Região - Sigla  ...                      Bandeira
# 0                 NE  ...                      IPIRANGA
# 1                 NE  ...                      IPIRANGA
# 2                 NE  ...                      IPIRANGA
# 3                 NE  ...  PETROBRAS DISTRIBUIDORA S.A.
# 4                 NE  ...  PETROBRAS DISTRIBUIDORA S.A.
# ...              ...  ...                           ...
# 47844             SE  ...                        BRANCA
# 47845             SE  ...                        BRANCA
# 47846             SE  ...                        BRANCA
# 47847             SE  ...                    RIO BRANCO
# 47848             SE  ...                    RIO BRANCO
#
# [47849 rows x 16 columns]

# %% [markdown]
# # **A fim de facilitar o processo de limpeza e tratamento dos dados, foi utilizada a função .concat() para juntar os dois dataframes criados anteriormente em um só.**

# %%
dataframe = pd.concat([df_junho, df_julho])
dataframe
# Out:
#       Região - Sigla  ...                      Bandeira
# 0                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 1                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 2                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 3                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 4                  N  ...                        BRANCA
# ...              ...  ...                           ...
# 47844             SE  ...                        BRANCA
# 47845             SE  ...                        BRANCA
# 47846             SE  ...                        BRANCA
# 47847             SE  ...                    RIO BRANCO
# 47848             SE  ...                    RIO BRANCO
#
# [97586 rows x 16 columns]

# %% [markdown]
# #**Como boa prática, foi realizada uma cópia do dataframe concatenado. Desta forma, mantemos o original para referência, enquanto a cópia é utilizada para a limpeza de dados e as consultas exigidas.**

# %%
df_copia = dataframe.copy()
df_copia
# Out:
#       Região - Sigla  ...                      Bandeira
# 0                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 1                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 2                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 3                  N  ...  PETROBRAS DISTRIBUIDORA S.A.
# 4                  N  ...                        BRANCA
# ...              ...  ...                           ...
# 47844             SE  ...                        BRANCA
# 47845             SE  ...                        BRANCA
# 47846             SE  ...                        BRANCA
# 47847             SE  ...                    RIO BRANCO
# 47848             SE  ...                    RIO BRANCO
#
# [97586 rows x 16 columns]

# %% [markdown]
# # **Notamos que na coluna "Valor de Venda", os números são separados por vírgula (,) e isso poderia nos trazer alguns problemas. Foi feita a conversão em float (de vírgula para ponto) para evitar eventuais transtornos.**

# %% [markdown]
# # **E após a conversão foi feita a transformação dos valores de venda para float**

# %% [markdown]
# #**Usamos lambda para transformar o campo "Valor de Venda" para duas casas decimais.**

# %% [markdown]
# #**Após as transformações observamos as informações da tabela se observou que a coluna "Valor de Compra" tinha apenas informações nulas, então optamos pela exclusão. Concluímos que ela não influenciaria no resultado final. A coluna foi excluída usando drop.**

# %% [markdown]
# #**Tabela sem a coluna Valor de Compra**

# %% [markdown]
# #**Observamos que existia um número fora do padrão em "Número Rua". Retiramos a vírgula.**

# %% [markdown]
# #**Limpamos possíveis linhas duplicadas do dataframe. Observamos que o número de linhas permaneceu o mesmo.**

# %% [markdown]
# #**Listamos os produtos para verificar se há produtos estranhos na coluna.**

# %% [markdown]
# #**Renomeamos as colunas com underline entre as palavras para auxiliar nas consultas**
